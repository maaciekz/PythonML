# %%
import jsonlines
import numpy as np

# %% [raw]
#  Read data from json file (format ndjson)

# %%
file = open('all.ndjson',encoding='utf-8')

# %%
allScratches = jsonlines.Reader(file)
print()

# %%
for obj in allScratches:
    print(len(obj))
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# ...
